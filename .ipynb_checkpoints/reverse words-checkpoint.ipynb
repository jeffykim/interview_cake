# %% [markdown]
# You're working on a secret team solving coded transmissions.
#
# Your team is scrambling to decipher a recent message, worried it's a plot to break into a major European National Cake Vault.
# The message has been mostly deciphered, but all the words are backward! Your colleagues have handed off the last step to you.
#
# Write a function reverse_words() that takes a message as a list of characters and reverses the order of the words in place.
# ↴
#
# Why a list of characters instead of a string?
#
# The goal of this question is to practice manipulating strings in place. Since we're modifying the message, we need a mutable
# ↴ type like a list, instead of Python 3.6's immutable strings.
#
# For example:
#
# message = [ 'c', 'a', 'k', 'e', ' ',
#             'p', 'o', 'u', 'n', 'd', ' ',
#             's', 't', 'e', 'a', 'l' ]
#
# reverse_words(message)
#
# #  Prints: 'steal pound cake'
# print(''.join(message))
#
# When writing your function, assume the message contains only letters and spaces, and all words are separated by one space.

# %%
import unittest

# %%
# reverse character test

class Test(unittest.TestCase):

    def test_empty_string(self):
        list_of_chars = []
        reverse(list_of_chars)
        expected = []
        self.assertEqual(list_of_chars, expected)

    def test_single_character_string(self):
        list_of_chars = ['A']
        reverse(list_of_chars)
        expected = ['A']
        self.assertEqual(list_of_chars, expected)

    def test_longer_string(self):
        list_of_chars = ['A', 'B', 'C', 'D', 'E']
        reverse(list_of_chars)
        expected = ['E', 'D', 'C', 'B', 'A']
        self.assertEqual(list_of_chars, expected)

if __name__=='__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False,verbosity=2)
# Out:
# test_empty_string (__main__.Test) ... ERROR
# test_longer_string (__main__.Test) ... ERROR
# test_single_character_string (__main__.Test) ... ERROR
#
# ======================================================================
# ERROR: test_empty_string (__main__.Test)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-2-6311a86a218b>", line 7, in test_empty_string
#     reverse(list_of_chars)
# NameError: name 'reverse' is not defined
#
# ======================================================================
# ERROR: test_longer_string (__main__.Test)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-2-6311a86a218b>", line 19, in test_longer_string
#     reverse(list_of_chars)
# NameError: name 'reverse' is not defined
#
# ======================================================================
# ERROR: test_single_character_string (__main__.Test)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-2-6311a86a218b>", line 13, in test_single_character_string
#     reverse(list_of_chars)
# NameError: name 'reverse' is not defined
#
# ----------------------------------------------------------------------
# Ran 3 tests in 0.014s
#
# FAILED (errors=3)

# %%
def reverse_characters(message):
    start= 0
    end = len(message)-1
    
    while start<end:
        message[start], message[end] = message[end], message[start]
        
        start+=1
        end-=1
        
    return message
        
    

    #first reverse all the entire message

# %%
def reverse_words(message):
    #reverse the list of characters
    reverse_characters(message)
    
    #define a starting index
    
    start_index = 0
    #end index is the last character
    
    #define the first ending index


    #for loop and reverse the characters again per word.

# %%
class Test(unittest.TestCase):

    def test_one_word(self):
        message = list('vault')
        reverse_words(message)
        expected = list('vault')
        self.assertEqual(message, expected)

    def test_two_words(self):
        message = list('thief cake')
        reverse_words(message)
        expected = list('cake thief')
        self.assertEqual(message, expected)

    def test_three_words(self):
        message = list('one another get')
        reverse_words(message)
        expected = list('get another one')
        self.assertEqual(message, expected)

    def test_multiple_words_same_length(self):
        message = list('rat the ate cat the')
        reverse_words(message)
        expected = list('the cat ate the rat')
        self.assertEqual(message, expected)

    def test_multiple_words_different_lengths(self):
        message = list('yummy is cake bundt chocolate')
        reverse_words(message)
        expected = list('chocolate bundt cake is yummy')
        self.assertEqual(message, expected)

    def test_empty_string(self):
        message = list('')
        reverse_words(message)
        expected = list('')
        self.assertEqual(message, expected)

if __name__=='__main__':
    unittest.main(argv=['first-arg-is-ignored'], exit=False,verbosity=2)
# Out:
# test_empty_string (__main__.Test) ... ERROR
# test_multiple_words_different_lengths (__main__.Test) ... ERROR
# test_multiple_words_same_length (__main__.Test) ... ERROR
# test_one_word (__main__.Test) ... ERROR
# test_three_words (__main__.Test) ... ERROR
# test_two_words (__main__.Test) ... ERROR
#
# ======================================================================
# ERROR: test_empty_string (__main__.Test)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-1-ea4d4b4fe78a>", line 37, in test_empty_string
#     reverse_words(message)
# NameError: name 'reverse_words' is not defined
#
# ======================================================================
# ERROR: test_multiple_words_different_lengths (__main__.Test)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-1-ea4d4b4fe78a>", line 31, in test_multiple_words_different_lengths
#     reverse_words(message)
# NameError: name 'reverse_words' is not defined
#
# ======================================================================
# ERROR: test_multiple_words_same_length (__main__.Test)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-1-ea4d4b4fe78a>", line 25, in test_multiple_words_same_length
#     reverse_words(message)
# NameError: name 'reverse_words' is not defined
#
# ======================================================================
# ERROR: test_one_word (__main__.Test)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-1-ea4d4b4fe78a>", line 7, in test_one_word
#     reverse_words(message)
# NameError: name 'reverse_words' is not defined
#
# ======================================================================
# ERROR: test_three_words (__main__.Test)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-1-ea4d4b4fe78a>", line 19, in test_three_words
#     reverse_words(message)
# NameError: name 'reverse_words' is not defined
#
# ======================================================================
# ERROR: test_two_words (__main__.Test)
# ----------------------------------------------------------------------
# Traceback (most recent call last):
#   File "<ipython-input-1-ea4d4b4fe78a>", line 13, in test_two_words
#     reverse_words(message)
# NameError: name 'reverse_words' is not defined
#
# ----------------------------------------------------------------------
# Ran 6 tests in 0.015s
#
# FAILED (errors=6)
